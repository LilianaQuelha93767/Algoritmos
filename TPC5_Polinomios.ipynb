# %% [markdown]
# ## Manifesto do TPC5
# * *Identificador:* Algoritmos e Técnicas de Programação
# * *Título:* Calculadora de Polinómios
# * *Data de início:* 2021-11-17
# * *Data de fim:* 2021-10-18
# * *Supervisor:* José Carlos Leite Ramalho, jcr@di.uminho.pt
# * *Autor:* Liliana Miranda Quelha A93767
# * *Resumo:* Este trabalho tem como objetivo criar uma aplicação que utiliza uma série de operações que especificamente lidam com __polinómios__

# %%
def menu():
    print("""Trabalhar com Polinómios
(1) Criar um Polinómio
(2) Calcular um Polinómio para vários x
(3) Gerar um Polinómio para uma tabela de valores de x
(4) Simplificar o Polinómio
(5) Calcular a derivada de um Polinómio
(0) Sair""")
menu()

#Criar Termos e inserir no Polinómio para formá-lo
def criarTermo(t):
    coeficiente = int(input("Introduza o coeficiente do Polinómio:"))
    expoente = int(input("Introduza o expoente: "))
    term = (coeficiente, expoente)
    return term
    
def criarPolinomio(p):
    n = int(input("Introduza o comprimento que deseja para o Polinómio: "))
    polinomio = []
    i = 0
    while i < n:
        polinomio.append(verTermo())
        i += 1
    return polinomio

#Calcular um Polinómio para o valor que atribuímos a x
x = int(input("Introduza o número que deseja atribuir a x: "))
def calcPol(p, x):
    valor = 0
    for term in p:
        coef, exp = term
        valor = valor + coef*x**exp
    return valor

#Calcular um Polinómio para os valores de x de uma tabela
l = int(input("Introduza o número de linhas que deseja que a tabela possua: "))
def tabela(p, l):
    for i in range (0, l):
        print(str(i) + "::" + str(calcPol(p,i))

# Colocar por ordem um Polinómio            
def ordenarPol(p):
    p.sort = (key = chaveOrd)
"""
def ordenarPol(p):
    i = 0
    c, e = p[i]
"""          

# Simplificar um Polinómio
def simplePol(p):
    ordenarPol(p)
    resLista = []
    for i in range (1, len(p)):
        c,e = p[i]
        c0, e0 = p[i-1]
        if e0 == e:
            inserirTermo(resLista(e + e0, e))
        else:
            if e0 > e:
              if i == 1:
                  inserirTermo(resLista(c0, e0))
            else:
              inserirTermo(resLista, (c, e))
    return resLista

#Calcular a derivada de um Polinómio
def derivarPol(p):
    res = []
    for t in p:
        c, e = t:
            res.append((c*e, e-1))
    return res  

print(verPolinomio(derivarPol(p2)))  

def verPolinomio(p):
    res = ""
    for t in p:
        if res == "":
            res = verTermo(t)
        else:
            res = res + "+" + verTermo(t)
    print(res)

        
op = "1"
while op != "0":
    menu()
    op = input("Qual é a sua opção? ")
    if op == "1":
        polinomio1 = criarPolinomio()
        print(polinomio1)
    elif op == "2":
        list = calcPol()
        print(lis)
    elif op == "0":
        print("Obrigado. E até à proxima!")
    elif op == "3":
        lis2 = tabela()
        print(lis2)
    elif op == "4":
        lis3 = ordenarPol()
        print(lis3)
    elif op == "5":
        lis4 = simplePol()
        print(lis4)
    elif op == "6":
        lis5 = derivarPol()
        print(lis5)
    else:
        print ("Opção Inválida!")
# Out:
#   File "<ipython-input-4-02708b3d84ae>", line 43
#     def ordenarPol(p):
#     ^
# SyntaxError: invalid syntax
